# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
import matplotlib.pyplot as plt


import numpy as np
import _pickle as cPickle
import os
import gzip
# Out:
# <style>.container { width:100% !important; }</style>

# %%
def plot_loss_and_error(name):
    figure_width = 10
    figure_height = 4
    figure_size = (figure_width, figure_height)

    title_font_size = 18
    label_font_size = 16

    plt.figure(figsize=figure_size)
    plt.title("Errors", fontsize = title_font_size)
    plt.plot(train_errors, label="train_errors")
    plt.plot(validation_errors, label="test_errors")
    plt.xlabel("epochs", fontsize = label_font_size)
    plt.ylabel("error", fontsize = label_font_size)
    plt.grid()
    plt.legend()
    plt.savefig("images/"+ name + "_Errors.jpg")
    plt.show()


    plt.figure(figsize=figure_size)
    plt.title("Loss", fontsize = title_font_size)
    plt.plot(train_losses, label="train_losses")
    plt.plot(validation_losses, label="test")
    plt.xlabel("epochs", fontsize = label_font_size)
    plt.ylabel("loss", fontsize = label_font_size)
    plt.grid()
    plt.legend()
    plt.savefig("images/"+ name + "_Losses.jpg")
    plt.show()

# %% [markdown]
# # First exercise: Classifying MNIST with MLPs
# In this exercise you will implement a Neural Network (or MLP) and classify the MNIST digits with it.
# MNIST is a "well hung" dataset that has been used a lot over the years to benchmark different classification algorithms.
# To learn more about it have a look here: http://yann.lecun.com/exdb/mnist/ .

# %% [markdown]
# # Data Loading
# We first define a function for downloading and loading MNIST.
# **WARNING**: Executing it will obviously use up some space on your machine ;).

# %%
def mnist(datasets_dir='./data'):
    if not os.path.exists(datasets_dir):
        os.mkdir(datasets_dir)
    data_file = os.path.join(datasets_dir, 'mnist.pkl.gz')
    if not os.path.exists(data_file):
        print('... downloading MNIST from the web')
        try:
            import urllib
            urllib.urlretrieve('http://google.com')
        except AttributeError:
            import urllib.request as urllib
        url = 'http://www.iro.umontreal.ca/~lisa/deep/data/mnist/mnist.pkl.gz'
        urllib.urlretrieve(url, data_file)

    print('... loading data')
    # Load the dataset
    f = gzip.open(data_file, 'rb')
    try:
        train_set, valid_set, test_set = cPickle.load(f, encoding="latin1")
    except TypeError:
        train_set, valid_set, test_set = cPickle.load(f)
    f.close()

    test_x, test_y = test_set
    test_x = test_x.astype('float32')
    test_x = test_x.astype('float32').reshape(test_x.shape[0], 1, 28, 28)
    test_y = test_y.astype('int32')
    valid_x, valid_y = valid_set
    valid_x = valid_x.astype('float32')
    valid_x = valid_x.astype('float32').reshape(valid_x.shape[0], 1, 28, 28)
    valid_y = valid_y.astype('int32')
    train_x, train_y = train_set
    train_x = train_x.astype('float32').reshape(train_x.shape[0], 1, 28, 28)
    train_y = train_y.astype('int32')
    rval = [(train_x, train_y), (valid_x, valid_y), (test_x, test_y)]
    print('... done loading data')
    return rval

# %% [markdown]
# # Neural Network Layers
# We now define "bare bone" neural network layers.
# The parts marked with **TODO** are where you should finish the implementation!
# Conceptually we will implement the layers as follows:
#
# Each layer has a constructor that takes an input layer plus some additional arguments such as layer size and the activation function name. The layer then uses the provided input layer to compute the layer dimensions, weight shapes, etc. and setup all auxilliary variables.
#
# Each layer then has to provide three functions (as defined in the Layer class below): *output_shape()*, *fprop()* and *brop()*. The output_shape function is used to figure out the shape for the next layer and the *fprop()/bprop()* functions are used to compute forward and backward passes through the network.

# %%
# start by defining simple helpers
def sigmoid(x):
    return 1.0/(1.0+np.exp(-x))

def sigmoid_d(x):
    r = sigmoid(x)
    return r * (1 - r)

def tanh(x):
    return np.tanh(x)

def tanh_d(x):
    tnh = tanh(x)
    return 1 - tnh*tnh

def relu(x):
    return np.maximum(0.0, x)

def relu_d(x):
    return x > 0.0

def softmax(x, axis=1):
    # to make the softmax a "safe" operation we will 
    # first subtract the maximum along the specified axis
    # so that np.exp(x) does not blow up!
    # Note that this does not change the output.
    x_max = np.max(x, axis=axis, keepdims=True)
    x_safe = x - x_max
    e_x = np.exp(x_safe)
    return e_x / np.sum(e_x, axis=axis, keepdims=True)

def one_hot(labels):
    """this creates a one hot encoding from a flat vector:
    i.e. given y = [0,2,1]
     it creates y_one_hot = [[1,0,0], [0,0,1], [0,1,0]]
    """
    classes = np.unique(labels)
    n_classes = classes.size
    one_hot_labels = np.zeros(labels.shape + (n_classes,))
    for c in classes:
        one_hot_labels[labels == c, c] = 1
    return one_hot_labels

def unhot(one_hot_labels):
    """ Invert a one hot encoding, creating a flat vector """
    return np.argmax(one_hot_labels, axis=-1) ## QUESTION: WHY -1?

# then define an activation function class
class Activation(object):
    
    def __init__(self, tname):
        if tname == 'sigmoid':
            self.act = sigmoid
            self.act_d = sigmoid_d
        elif tname == 'tanh':
            self.act = tanh
            self.act_d = tanh_d
        elif tname == 'relu':
            self.act = relu
            self.act_d = relu_d
        else:
            raise ValueError('Invalid activation function.')
            
    def fprop(self, input):
        # we need to remember the last input
        # so that we can calculate the derivative with respect
        # to it later on
        self.last_input = input
        return self.act(input)
    
    def bprop(self, output_grad):
        return output_grad * self.act_d(self.last_input)

# define a base class for layers
class Layer(object):
    
    def fprop(self, input):
        """ Calculate layer output for given input 
            (forward propagation). 
        """
        raise NotImplementedError('This is an interface class, please use a derived instance')

    def bprop(self, output_grad):
        """ Calculate input gradient and gradient 
            with respect to weights and bias (backpropagation). 
        """
        raise NotImplementedError('This is an interface class, please use a derived instance')

    def output_size(self):
        """ Calculate size of this layer's output.
        input_shape[0] is the number of samples in the input.
        input_shape[1:] is the shape of the feature.
        """
        raise NotImplementedError('This is an interface class, please use a derived instance')

# define a base class for loss outputs
# an output layer can then simply be derived
# from both Layer and Loss 
class Loss(object):

    def loss(self, output, output_net):
        """ Calculate mean loss given real output and network output. """
        raise NotImplementedError('This is an interface class, please use a derived instance')

    def input_grad(self, output, output_net):
        """ Calculate input gradient real output and network output. """
        raise NotImplementedError('This is an interface class, please use a derived instance')

# define a base class for parameterized things        
class Parameterized(object):
    
    def params(self):
        """ Return parameters (by reference) """
        raise NotImplementedError('This is an interface class, please use a derived instance')
    
    def grad_params(self):
        """ Return accumulated gradient with respect to params. """
        raise NotImplementedError('This is an interface class, please use a derived instance')

# define a container for providing input to the network
class InputLayer(Layer):
    
    def __init__(self, input_shape): ## batch_size * num_units_prev?
        if not isinstance(input_shape, tuple):
            raise ValueError("InputLayer requires input_shape as a tuple")
        self.input_shape = input_shape

    def output_size(self):
        return self.input_shape
    
    def fprop(self, input):
        return input
    
    def bprop(self, output_grad):
        return output_grad
        
class FullyConnectedLayer(Layer, Parameterized):
    """ A standard fully connected hidden layer, as discussed in the lecture.
    """
    
    def __init__(self, input_layer, num_units,
                 init_stddev, activation_fun=Activation('relu')):
        self.num_units = num_units
        self.activation_fun = activation_fun
        # the input shape will be of size (batch_size, num_units_prev) 
        # where num_units_prev is the number of units in the input 
        # (previous) layer
        self.input_shape = input_layer.output_size()
        num_units_prev = self.input_shape[1]
        # this is the weight matrix it should have shape: (num_units_prev, num_units)
        self.W = np.random.normal(loc=0.0, scale=init_stddev, size=(num_units_prev, num_units))
        # and this is the bias vector of shape: (num_units)
        self.b = np.random.normal(loc=0.0, scale=init_stddev, size=(num_units))
        # create dummy variables for parameter gradients
        # no need to change these here!
        self.dW = None
        self.db = None
    
    def output_size(self):
        return (self.input_shape[0], self.num_units) ## batch size * number of neurons in layer

    def fprop(self, input):
        # implement forward propagation
        # NOTE: you should also handle the case were 
        #       activation_fun is None (meaning no activation)
        #       then this is simply a linear layer
        # you again want to cache the last_input for the bprop
        # implementation below!
        self.last_input = input
        # NOTE: Use numpy dot product
        # h = t(a), a = W * x + b
        
        h = np.dot(input, self.W) + self.b 
        if self.activation_fun is not None:
            h = self.activation_fun.fprop(h)
        return h
        
    def bprop(self, output_grad):
        """ Calculate input gradient (backpropagation). """
        #################################
        # implement backward propagation
        #################################
        
        # HINT: you may have to divide dW and db by n
        #       to make gradient checking work 
        #       OR you divide the gradient in the output layer by n
        n = output_grad.shape[0]
        # accumulate gradient wrt. the parameters first
        # we will need to store these to later update
        # the network after a few forward backward passes
        # NOTE: you should also handle the case were 
        #       activation_fun is None (meaning no activation)
        # the gradient wrt. W should be stored as self.dW
        # the gradient wrt. b should be stored as selfdb
        # NOTE: self.dW is also a numpy dot product
        
        if self.activation_fun is not None:
            output_grad = self.activation_fun.bprop(output_grad)
            
        self.dW = np.dot(self.last_input.T, output_grad) * (1/n)
        self.db = np.sum(output_grad, axis=0, keepdims = False) * (1/n)
 
        # the gradient wrt. the input should be calculated here
        grad_input = np.dot(output_grad, self.W.T)
        return grad_input
        
    def params(self):
        return self.W, self.b

    def grad_params(self):
        return self.dW, self.db
    
    def norm_of_params(self):
        return np.linalg.norm(self.W)+np.linalg.norm(self.b)

# finally we specify the interface for output layers 
# which are layers that also have a loss function
# we will implement two output layers:
#  a Linear, and Softmax (Logistic Regression) layer
# The difference between output layers and and normal 
# layers is that they will be called to compute the gradient
# of the loss through input_grad(). bprop will never 
# be called on them!
class LinearOutput(Layer, Loss):
    """ A simple linear output layer that  
        uses a squared loss (e.g. should be used for regression)
    """
    def __init__(self, input_layer):
        self.input_size = input_layer.output_size()
        
    def output_size(self):
        return (1,)
        
    def fprop(self, input):
        return input

    def bprop(self, output_grad):
        raise NotImplementedError(
            'LinearOutput should only be used as the last layer of a Network'
            + ' bprop() should thus never be called on it!'
        )
    
    def input_grad(self, Y, Y_pred):
        #####################################
        # implement gradient of squared loss
        #####################################
        return Y_pred - Y

    def loss(self, Y, Y_pred):
        loss = 0.5 * np.square(Y_pred - Y)
        return np.mean(np.sum(loss, axis=1))

class SoftmaxOutput(Layer, Loss):
    """ A softmax output layer that calculates 
        the negative log likelihood as loss
        and should be used for classification.
    """
    
    def __init__(self, input_layer):
        self.input_size = input_layer.output_size()
        
    def output_size(self):
        return (1,)
    
    def fprop(self, input):
        return softmax(input)
    
    def bprop(self, output_grad):
        raise NotImplementedError(
            'SoftmaxOutput should only be used as the last layer of a Network'
            + ' bprop() should thus never be called on it!'
        )
    
    def input_grad(self, Y, Y_pred):
        ########################################################
        # implement gradient of the negative log likelihood loss
        ########################################################
        # HINT: since this would involve taking the log 
        #       of the softmax (which is np.exp(x)/np.sum(x, axis=1))
        #       this gradient computation can be simplified a lot,
        #       you may find a connection to the LinearOutput layer!
        return Y_pred - Y
#     def input_grad(self, Y, Y_pred, regulator):
#         ########################################################
#         # implement gradient of the negative log likelihood loss
#         ########################################################
#         # HINT: since this would involve taking the log 
#         #       of the softmax (which is np.exp(x)/np.sum(x, axis=1))
#         #       this gradient computation can be simplified a lot,
#         #       you may find a connection to the LinearOutput layer!
#         return Y_pred - Y + regulator

    def loss(self, Y, Y_pred):
        # Assume one-hot encoding of Y
        out = Y_pred
        # to make the loss numerically stable 
        # you should add an epsilon in the log ;)
        eps = 1e-10
        #####################################
        # calculate negative log likelihood
        #####################################
        loss = -np.log(Y_pred + eps) * Y
        return np.mean(np.sum(loss, axis=1))

# %%
## Testing in the linear case

x = np.linspace(-4,4,100)

### test derivatives of sigmoid
y_sigmoid = sigmoid(x)
y_sigmoid_d = sigmoid_d(x)

plt.title("Sigmoid visualization")
plt.plot(x, y_sigmoid, label="sigmoid")
plt.plot(x, y_sigmoid_d, label="sigmoid_d")
plt.grid()
plt.legend()
plt.xlabel("x")
plt.ylabel("y")
plt.savefig("images/activation_functions/sigmoid.jpg")
plt.show()

### test derivatives of tanh
y_tanh = tanh(x)
y_tanh_d = tanh_d(x)
plt.title("Tanh visualization")
plt.plot(x, y_tanh, label="tanh")
plt.plot(x, y_tanh_d, label="tanh_d")
plt.grid()
plt.legend()
plt.xlabel("x")
plt.ylabel("y")
plt.savefig("images/activation_functions/tanh.jpg")
plt.show()


### test derivatives of relu
y_relu = relu(x)
y_relu_d = relu_d(x)
plt.title("Relu visualization")
plt.plot(x, y_relu, label="relu")
plt.plot(x, y_relu_d, label="relu_d")
plt.grid()
plt.legend()
plt.xlabel("x")
plt.ylabel("y")
plt.savefig("images/activation_functions/relu.jpg")
plt.show()

# %%
## Testing in the 2-d case

x = np.array([[-1,4,5,15,2,-5],[-10,1,5,3,2,-7]])
print(x)
### test derivatives of sigmoid
y_sigmoid = sigmoid(x)
y_sigmoid_d = sigmoid_d(x)

plt.title("Sigmoid visualization")
plt.plot(x, y_sigmoid)
plt.plot(x, y_sigmoid_d)
plt.grid()
plt.show()

### test derivatives of tanh
y_tanh = tanh(x)
y_tanh_d = tanh_d(x)
plt.title("Tanh visualization")
plt.plot(x, y_tanh)
plt.plot(x, y_tanh_d)
plt.grid()
plt.show()


### test derivatives of relu
y_relu = relu(x)
y_relu_d = relu_d(x)
plt.title("Relu visualization")
plt.plot(x, y_relu)
plt.plot(x, y_relu_d)
plt.grid()
plt.show()
# Out:
# [[ -1   4   5  15   2  -5]
#  [-10   1   5   3   2  -7]]

# %% [markdown]
# # Neural Network class
# With all layers in place (and properly implemented by you) we can finally define a neural network.
# For our purposes a neural network is simply a collection of layers which we will cycle through and on which we will call fprop and bprop to compute partial derivatives with respect to the input and the parameters.
#
# Pay special attention to the *check_gradients()* function in which you should implement automatic differentiation. This function will become your best friend when checking the correctness of your implementation.

# %%
class NeuralNetwork:
    """ Our Neural Network container class.
    """
    def __init__(self, layers):
        print("New Neural Network constructed")
        # for layer in layers: # [0:-1]:
            #print("Output size of layer: ", layer.output_size())
        self.layers = layers
        
    def _loss(self, X, Y):
        Y_pred = self.predict(X)
        return self.layers[-1].loss(Y, Y_pred)

    def predict(self, X):
        """ Calculate an output Y for the given input X. """
        ###########################################
        # implement forward pass through all layers
        ###########################################
        Y_pred = X.copy()
        for layer in self.layers:
            Y_pred = layer.fprop(Y_pred)
            
        return Y_pred
    
    def backpropagate(self, Y, Y_pred, upto=0):
        """ Backpropagation of partial derivatives through 
            the complete network up to layer 'upto'
        """
        # regulator = self.regularization_norm()
        next_grad = self.layers[-1].input_grad(Y, Y_pred) #, regulator)
        ###########################################
        # implement backward pass through all layers
        ###########################################
        
        for ind in range(upto, len(self.layers)-1)[::-1]: ## [::-1] inverts the order
            next_grad = self.layers[ind].bprop(next_grad)
        
        return next_grad
    
    def classification_error(self, X, Y):
        """ Calculate error on the given data 
            assuming they are classes that should be predicted. 
        """
        Y_pred = unhot(self.predict(X))
        error = Y_pred != Y
        return np.mean(error)
    
    def sgd_epoch(self, X, Y, learning_rate, batch_size):
        #         print("sgd_epoch called with X = \n", X, "\nY = \n", Y,
        #               "\nlearning_rate = \n", learning_rate, "\n batch_size = \n",
        #               batch_size)
        
        n_samples = X.shape[0]
        n_batches = n_samples // batch_size ## whole number division
        print("n_samples:\n", n_samples)
        print("n_batches:\n", n_batches)
        
        X_batches = np.array_split(X, n_batches)
        Y_batches = np.array_split(Y, n_batches)

        ######################################
        # Implement stochastic gradient descent here
        ######################################
        # start by extracting a batch from X and Y
        # (you can assume the inputs are already shuffled)
        # num_runs = ## QUESTION: ?!

        for n_batch in range(n_batches):
            # print("Batch %d running.." % n_batch)
            X_batch = X_batches[n_batch]
            Y_batch = Y_batches[n_batch]
            
            Y_batch_pred = self.predict(X_batch)
            gradient = self.backpropagate(Y_batch, Y_batch_pred)
            
            for layer in self.layers[1:-1]:
                W, b = layer.params()
                dW, db = layer.grad_params()
                W -= learning_rate * dW
                b -= learning_rate * db
            # print("Batch %d finished!" % n_batch)
        # then forward and backward propagation + updates
        # HINT: layer.params() returns parameters *by reference*
        #       so you can easily update in-place
        pass
    
    def gd_epoch(self, X, Y, learning_rate):
        ###################################################
        # Implement batch gradient descent here
        # A few hints:
        #   There are two strategies you can follow:
        #   Either shove the whole dataset throught the network
        #   at once (which can be problematic for large datasets)
        #   or run through it batch wise as in the sgd approach
        #   and accumulate the gradients for all parameters as
        #   you go through the data. Either way you should then
        #   do one gradient step after you went through the
        #   complete dataset!
        ###################################################
        
            
        Y_pred = self.predict(X)
        gradient = self.backpropagate(Y, Y_pred)
                        
        for i in range(1, len(self.layers)-1):
            W, b = self.layers[i].params()
            dW, db = self.layers[i].grad_params()
            W -= learning_rate * dW
            b -= learning_rate * db
        
        pass
    
    def train(self, X, Y, X_valid, Y_valid, learning_rate=0.1, max_epochs=100, batch_size=64,
              descent_type="sgd", y_one_hot=True):

        """ Train network on the given data. """
        n_samples = X.shape[0]
        n_batches = n_samples // batch_size
        if y_one_hot:
            Y_train = one_hot(Y)
            Y_valid = one_hot(Y_valid) ###
        else:
            Y_train = Y
            
        train_losses = []
        train_errors = []
        validation_losses = []
        validation_errors = []
        
        print("... starting training")
        for e in range(max_epochs+1):
            if descent_type == "sgd":
                self.sgd_epoch(X, Y_train, learning_rate, batch_size)
            elif descent_type == "gd":
                self.gd_epoch(X, Y_train, learning_rate)
            else:
                raise NotImplementedError("Unknown gradient descent type {}".format(descent_type))

            # Output error on the training data
            train_loss = self._loss(X, Y_train)
            train_error = self.classification_error(X, Y)
            print('epoch {:.0f}, loss {:.4f}, train error {:.4f}'.format(e, train_loss, train_error))
            ###################################################
            # compute error on validation data:
            # simply make the function take validation data as input
            # and then compute errors here and print them
            ###################################################
            validation_loss = self._loss(X_valid, Y_valid)
            validation_error = self.classification_error(X_valid, unhot(Y_valid))
            print('epoch {:.0f}, loss {:.4f}, validation error {:.4f}'.format(e, validation_loss, validation_error))
            train_losses.append(train_loss)
            train_errors.append(train_error)
            validation_losses.append(validation_loss)
            validation_errors.append(validation_error)
            
        return train_losses, train_errors, validation_losses, validation_errors
        
    
    def regularization_norm(self):
        sum = 0
        for layer in self.layers[1:-1]:
            sum += layer.norm_of_params()
        return sum
    
    
    def check_gradients(self, X, Y):
        """ Helper function to test the parameter gradients for
        correctness. """
        for l, layer in enumerate(self.layers):
            if isinstance(layer, Parameterized):
                print('checking gradient for layer {}'.format(l))
                for p, param in enumerate(layer.params()):
                    # we iterate through all parameters
                    param_shape = param.shape
                    # define functions for conveniently swapping
                    # out parameters of this specific layer and 
                    # computing loss and gradient with these 
                    # changed parametrs
                    def output_given_params(param_new):
                        """ A function that will compute the output 
                            of the network given a set of parameters
                        """
                        # copy provided parameters
                        param[:] = np.reshape(param_new, param_shape)
                        # return computed loss
                        return self._loss(X, Y)

                    def grad_given_params(param_new):
                        """A function that will compute the gradient 
                           of the network given a set of parameters
                        """
                        # copy provided parameters
                        param[:] = np.reshape(param_new, param_shape)
                        # Forward propagation through the net
                        Y_pred = self.predict(X)
                        # Backpropagation of partial derivatives
                        self.backpropagate(Y, Y_pred, upto=l)
                        # return the computed gradient 
                        return np.ravel(self.layers[l].grad_params()[p]) 

                    # let the initial parameters be the ones that
                    # are currently placed in the network and flatten them
                    # to a vector for convenient comparisons, printing etc.
                    param_init = np.ravel(np.copy(param))
                    
                    # To debug you network's gradients use scipys
                    # gradient checking!
                    epsilon = 1e-5
                    import scipy.optimize
                    err = scipy.optimize.check_grad(output_given_params, 
                          grad_given_params,
                          param_init) 
                    print('diff scipy {:.2e}'.format(err))
                    assert(err < epsilon)
                    
                    # reset the parameters to their initial values
                    param[:] = np.reshape(param_init, param_shape)

# %% [markdown]
# # Gradient Checking
# After implementing everything it is always a good idea to setup some layers and perform gradient
# checking on random data. **Note** that this is only an example! It is not a useful network architecture ;). We also expect you to play around with this to test all your implemented components.

# %%
input_shape = (5, 10)
n_labels = 6
layers = [InputLayer(input_shape)]

layers.append(FullyConnectedLayer(
                layers[-1],
                num_units= 14,
                init_stddev=0.1,
                activation_fun=Activation('relu')
))
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units= 6,
                init_stddev=0.1,
                activation_fun=Activation('tanh')
))
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=n_labels,
                init_stddev=0.1,
                activation_fun=Activation('relu')
))
layers.append(SoftmaxOutput(layers[-1]))
nn = NeuralNetwork(layers)
# Out:
# New Neural Network constructed

# %%
# create random data
X = np.random.normal(size=input_shape)
# and random labels
Y = np.zeros((input_shape[0], n_labels))
for i in range(Y.shape[0]):
    idx = np.random.randint(n_labels)
    Y[i, idx] = 1.

# %%
nn.check_gradients(X, Y)
# Out:
# checking gradient for layer 1
# diff scipy 8.95e-08
# diff scipy 1.60e-08
# checking gradient for layer 2
# diff scipy 6.31e-08
# diff scipy 2.34e-08
# checking gradient for layer 3
# diff scipy 1.85e-08
# diff scipy 1.41e-08

# %% [markdown]
# # Training on MNIST
# Finally we can let our network run on the MNIST dataset!

# %% [markdown]
# First load the data and reshape it.

# %%
# load
Dtrain, Dval, Dtest = mnist()
X_train, y_train = Dtrain
X_valid, y_valid = Dval
X_test, y_test = Dtest
# Out:
# ... loading data
# ... done loading data

# %% [markdown]
# *Dtrain* contains 50k images which are of size 28 x 28 pixels. Hence:

# %%
print("X_train shape: {}".format(np.shape(X_train)))
print("y_train shape: {}".format(np.shape(y_train)))
# Out:
# X_train shape: (50000, 1, 28, 28)
# y_train shape: (50000,)

# %% [markdown]
# y_train will automatically be converted in the *train()* function to one_hot encoding.
#
#
# But we need to reshape X_train, as our Network expects flat vectors of size 28*28 as input!

# %%
X_train = X_train.reshape(X_train.shape[0], -1)
print("Reshaped X_train size: {}".format(X_train.shape))
X_valid = X_valid.reshape((X_valid.shape[0], -1))
print("Reshaped X_valid size: {}".format(X_valid.shape))
X_test = X_test.reshape((X_test.shape[0], -1))
print("Reshaped X_test size: {}".format(X_test.shape))
# Out:
# Reshaped X_train size: (50000, 784)
# Reshaped X_valid size: (10000, 784)
# Reshaped X_test size: (10000, 784)

# %%
X_full = np.append(X_train, X_valid, axis=0)
print("Reshaped X_full size: {}".format(X_full.shape))

y_full = np.append(y_train, y_valid, axis=0)
print("Reshaped y_full size: {}".format(y_full.shape))
# Out:
# Reshaped X_full size: (60000, 784)
# Reshaped y_full size: (60000,)

# %% [markdown]
# Ah, much better ;-)!
#
# Now we can finally really start training a Network!
#
#
# I pre-defined a small Network for you below. Again This is not really a good default and will not produce state of the art results. Please play around with this a bit. See how different activation functions and training procedures (gd / sgd) affect the result.

# %%
import time

# Setup a small MLP / Neural Network
# we can set the first shape to None here to indicate that
# we will input a variable number inputs to the network
input_shape = (None, 28*28)
layers = [InputLayer(input_shape)]
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=200,
                init_stddev=0.2,
                activation_fun=Activation('relu')
))
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=100,
                init_stddev=0.1,
                activation_fun=Activation('relu')
))
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=10,
                init_stddev=0.01,
                # last layer has no nonlinearity 
                # (softmax will be applied in the output layer)
                activation_fun=None 
))
layers.append(SoftmaxOutput(layers[-1]))
nn_200r100r = NeuralNetwork(layers)

# %%
# training_size = 5000
# X_train = X_train[:training_size,:]
# y_train = y_train[:training_size]

# validation_size = 1000
# X_valid = X_valid[:validation_size,:]
# y_valid = y_valid[:validation_size]

# print("X_train.shape", X_train.shape)
# print("y_train.shape", y_train.shape)

# %%
# Train neural network
t0 = time.time()

train_losses, train_errors, validation_losses, validation_errors =  nn_200r100r.train(X_train, y_train, X_valid, y_valid, learning_rate = 0.08, max_epochs=100, batch_size=60, y_one_hot=True)
t1 = time.time()
print('Duration: {:.1f}s'.format(t1-t0))
plot_loss_and_error("nn_200r100r")

# %% [markdown]
# # Figure out a reasonable Network that achieves good performance
# As the last part of this task, setup a network that works well and gets reasonable accuracy, say ~ 1-3 percent error on the **validation set**.
# Train this network on the complete data and compute the **test error**.
#
# Visualize the validation loss and training loss for each iteration in a plot, e.g. using matplotlib

# %%
import time

# Setup a small MLP / Neural Network
# we can set the first shape to None here to indicate that
# we will input a variable number inputs to the network
input_shape = (None, 28*28)
layers = [InputLayer(input_shape)]
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=300,
                init_stddev=0.2,
                activation_fun=Activation('relu')
))
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=100,
                init_stddev=0.2,
                activation_fun=Activation('relu')
))
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=10,
                init_stddev=0.01,
                # last layer has no nonlinearity 
                # (softmax will be applied in the output layer)
                activation_fun=None 
))
layers.append(SoftmaxOutput(layers[-1]))
nn_300r200r = NeuralNetwork(layers)
# Out:
# New Neural Network constructed

# %%
# Train neural network
t0 = time.time()

train_losses, train_errors, validation_losses, validation_errors =  nn_300r100r100r.train(X_full, y_full, X_test, y_test, learning_rate = 0.08, max_epochs=30, batch_size=80, y_one_hot=True)
t1 = time.time()
print('Duration: {:.1f}s'.format(t1-t0))
plot_loss_and_error("nn_300r100r100r_test")
# Out:
# ... starting training
# n_samples:
#  60000
# n_batches:
#  750
# epoch 0, loss 0.2229, train error 0.0697
# epoch 0, loss 0.2373, validation error 0.0755
# n_samples:
#  60000
# n_batches:
#  750
# epoch 1, loss 0.1555, train error 0.0490
# epoch 1, loss 0.1865, validation error 0.0591
# n_samples:
#  60000
# n_batches:
#  750
# epoch 2, loss 0.1334, train error 0.0424
# epoch 2, loss 0.1824, validation error 0.0557
# n_samples:
#  60000
# n_batches:
#  750
# epoch 3, loss 0.1185, train error 0.0383
# epoch 3, loss 0.1827, validation error 0.0544
# n_samples:
#  60000
# n_batches:
#  750
# epoch 4, loss 0.1076, train error 0.0352
# epoch 4, loss 0.1832, validation error 0.0531
# n_samples:
#  60000
# n_batches:
#  750
# epoch 5, loss 0.0916, train error 0.0303
# epoch 5, loss 0.1770, validation error 0.0486
# n_samples:
#  60000
# n_batches:
#  750
# epoch 6, loss 0.0697, train error 0.0233
# epoch 6, loss 0.1651, validation error 0.0446
# n_samples:
#  60000
# n_batches:
#  750
# epoch 7, loss 0.0567, train error 0.0190
# epoch 7, loss 0.1581, validation error 0.0421
# n_samples:
#  60000
# n_batches:
#  750
# epoch 8, loss 0.0486, train error 0.0166
# epoch 8, loss 0.1575, validation error 0.0413
# n_samples:
#  60000
# n_batches:
#  750
# epoch 9, loss 0.0418, train error 0.0142
# epoch 9, loss 0.1595, validation error 0.0402
# n_samples:
#  60000
# n_batches:
#  750
# epoch 10, loss 0.0326, train error 0.0108
# epoch 10, loss 0.1576, validation error 0.0388
# n_samples:
#  60000
# n_batches:
#  750
# epoch 11, loss 0.0256, train error 0.0083
# epoch 11, loss 0.1567, validation error 0.0382
# n_samples:
#  60000
# n_batches:
#  750
# epoch 12, loss 0.0192, train error 0.0061
# epoch 12, loss 0.1558, validation error 0.0358
# n_samples:
#  60000
# n_batches:
#  750
# epoch 13, loss 0.0150, train error 0.0046
# epoch 13, loss 0.1553, validation error 0.0350
# n_samples:
#  60000
# n_batches:
#  750
# epoch 14, loss 0.0123, train error 0.0036
# epoch 14, loss 0.1593, validation error 0.0345
# n_samples:
#  60000
# n_batches:
#  750
# epoch 15, loss 0.0101, train error 0.0027
# epoch 15, loss 0.1632, validation error 0.0347
# n_samples:
#  60000
# n_batches:
#  750
# epoch 16, loss 0.0083, train error 0.0021
# epoch 16, loss 0.1642, validation error 0.0341
# n_samples:
#  60000
# n_batches:
#  750
# epoch 17, loss 0.0066, train error 0.0015
# epoch 17, loss 0.1672, validation error 0.0343
# n_samples:
#  60000
# n_batches:
#  750
# epoch 18, loss 0.0055, train error 0.0012
# epoch 18, loss 0.1697, validation error 0.0339
# n_samples:
#  60000
# n_batches:
#  750
# epoch 19, loss 0.0046, train error 0.0009
# epoch 19, loss 0.1705, validation error 0.0337
# n_samples:
#  60000
# n_batches:
#  750
# epoch 20, loss 0.0039, train error 0.0008
# epoch 20, loss 0.1719, validation error 0.0336
# n_samples:
#  60000
# n_batches:
#  750
# epoch 21, loss 0.0034, train error 0.0005
# epoch 21, loss 0.1725, validation error 0.0334
# n_samples:
#  60000
# n_batches:
#  750
# epoch 22, loss 0.0025, train error 0.0003
# epoch 22, loss 0.1718, validation error 0.0330
# n_samples:
#  60000
# n_batches:
#  750
# epoch 23, loss 0.0020, train error 0.0001
# epoch 23, loss 0.1722, validation error 0.0319
# n_samples:
#  60000
# n_batches:
#  750
# epoch 24, loss 0.0017, train error 0.0001
# epoch 24, loss 0.1725, validation error 0.0314
# n_samples:
#  60000
# n_batches:
#  750
# epoch 25, loss 0.0015, train error 0.0000
# epoch 25, loss 0.1733, validation error 0.0309
# n_samples:
#  60000
# n_batches:
#  750
# epoch 26, loss 0.0013, train error 0.0000
# epoch 26, loss 0.1742, validation error 0.0308
# n_samples:
#  60000
# n_batches:
#  750
# epoch 27, loss 0.0012, train error 0.0000
# epoch 27, loss 0.1752, validation error 0.0306
# n_samples:
#  60000
# n_batches:
#  750
# epoch 28, loss 0.0010, train error 0.0000
# epoch 28, loss 0.1759, validation error 0.0305
# n_samples:
#  60000
# n_batches:
#  750
# epoch 29, loss 0.0009, train error 0.0000
# epoch 29, loss 0.1769, validation error 0.0304
# n_samples:
#  60000
# n_batches:
#  750
# epoch 30, loss 0.0009, train error 0.0000
# epoch 30, loss 0.1778, validation error 0.0303
# Duration: 2348.4s

# %%
# Out:
# ... starting training
# n_samples:
#  60000
# n_batches:
#  750
# epoch 0, loss 0.2270, train error 0.0708
# epoch 0, loss 0.2413, validation error 0.0737
# n_samples:
#  60000
# n_batches:
#  750
# epoch 1, loss 0.1497, train error 0.0460
# epoch 1, loss 0.1758, validation error 0.0538
# n_samples:
#  60000
# n_batches:
#  750
# epoch 2, loss 0.1153, train error 0.0353
# epoch 2, loss 0.1489, validation error 0.0463
# n_samples:
#  60000
# n_batches:
#  750
# epoch 3, loss 0.0946, train error 0.0286
# epoch 3, loss 0.1357, validation error 0.0418
# n_samples:
#  60000
# n_batches:
#  750
# epoch 4, loss 0.0796, train error 0.0239
# epoch 4, loss 0.1279, validation error 0.0388
# n_samples:
#  60000
# n_batches:
#  750
# epoch 5, loss 0.0685, train error 0.0211
# epoch 5, loss 0.1233, validation error 0.0376
# n_samples:
#  60000
# n_batches:
#  750
# epoch 6, loss 0.0585, train error 0.0178
# epoch 6, loss 0.1208, validation error 0.0369
# n_samples:
#  60000
# n_batches:
#  750
# epoch 7, loss 0.0502, train error 0.0152
# epoch 7, loss 0.1188, validation error 0.0359
# n_samples:
#  60000
# n_batches:
#  750
# epoch 8, loss 0.0431, train error 0.0132
# epoch 8, loss 0.1171, validation error 0.0345
# n_samples:
#  60000
# n_batches:
#  750
# epoch 9, loss 0.0371, train error 0.0115
# epoch 9, loss 0.1167, validation error 0.0343
# n_samples:
#  60000
# n_batches:
#  750
# epoch 10, loss 0.0321, train error 0.0098
# epoch 10, loss 0.1158, validation error 0.0340
# n_samples:
#  60000
# n_batches:
#  750
# epoch 11, loss 0.0277, train error 0.0083
# epoch 11, loss 0.1161, validation error 0.0337
# n_samples:
#  60000
# n_batches:
#  750
# epoch 12, loss 0.0244, train error 0.0073
# epoch 12, loss 0.1170, validation error 0.0331
# n_samples:
#  60000
# n_batches:
#  750
# epoch 13, loss 0.0216, train error 0.0065
# epoch 13, loss 0.1182, validation error 0.0326
# n_samples:
#  60000
# n_batches:
#  750
# epoch 14, loss 0.0194, train error 0.0057
# epoch 14, loss 0.1201, validation error 0.0329
# n_samples:
#  60000
# n_batches:
#  750
# epoch 15, loss 0.0175, train error 0.0049
# epoch 15, loss 0.1213, validation error 0.0330
# n_samples:
#  60000
# n_batches:
#  750
# epoch 16, loss 0.0152, train error 0.0041
# epoch 16, loss 0.1219, validation error 0.0322
# n_samples:
#  60000
# n_batches:
#  750
# epoch 17, loss 0.0135, train error 0.0035
# epoch 17, loss 0.1228, validation error 0.0322
# n_samples:
#  60000
# n_batches:
#  750
# epoch 18, loss 0.0119, train error 0.0029
# epoch 18, loss 0.1234, validation error 0.0318
# n_samples:
#  60000
# n_batches:
#  750
# epoch 19, loss 0.0106, train error 0.0024
# epoch 19, loss 0.1241, validation error 0.0311
# n_samples:
#  60000
# n_batches:
#  750
# epoch 20, loss 0.0094, train error 0.0019
# epoch 20, loss 0.1245, validation error 0.0308
# n_samples:
#  60000
# n_batches:
#  750
# epoch 21, loss 0.0083, train error 0.0016
# epoch 21, loss 0.1250, validation error 0.0305
# n_samples:
#  60000
# n_batches:
#  750
# epoch 22, loss 0.0076, train error 0.0014
# epoch 22, loss 0.1257, validation error 0.0307
# n_samples:
#  60000
# n_batches:
#  750
# epoch 23, loss 0.0067, train error 0.0010
# epoch 23, loss 0.1259, validation error 0.0303
# n_samples:
#  60000
# n_batches:
#  750
# epoch 24, loss 0.0059, train error 0.0007
# epoch 24, loss 0.1260, validation error 0.0299
# n_samples:
#  60000
# n_batches:
#  750
# epoch 25, loss 0.0050, train error 0.0005
# epoch 25, loss 0.1257, validation error 0.0297
# n_samples:
#  60000
# n_batches:
#  750
# epoch 26, loss 0.0045, train error 0.0004
# epoch 26, loss 0.1260, validation error 0.0294
# n_samples:
#  60000
# n_batches:
#  750
# epoch 27, loss 0.0040, train error 0.0003
# epoch 27, loss 0.1261, validation error 0.0294
# n_samples:
#  60000
# n_batches:
#  750
# epoch 28, loss 0.0037, train error 0.0003
# epoch 28, loss 0.1264, validation error 0.0291
# n_samples:
#  60000
# n_batches:
#  750
# epoch 29, loss 0.0034, train error 0.0002
# epoch 29, loss 0.1267, validation error 0.0290
# n_samples:
#  60000
# n_batches:
#  750
# epoch 30, loss 0.0031, train error 0.0001
# epoch 30, loss 0.1269, validation error 0.0287
# Duration: 2114.6s

# %%
print("Final test error:", validation_errors[-1])
# Out:
# Final test error: 0.0287
